# %%
import os
from typing import TypedDict, List, Optional
from pydantic import BaseModel, Field, AliasChoices
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
from langgraph.graph import StateGraph, END
from constants import BASE_URL, API_KEY, MODEL_NAME

# %%
# Схемы данных (Pydantic)

class Topic(BaseModel):
    title: str = Field(description="Заголовок темы")
    # Делаем тег необязательным. Если его нет, будет пустая строка или default.
    tag: Optional[str] = Field(
        default="#general", 
        description="Тематический тег, например #ai / #жизньвКитае"
    )
    # Позволяем модели называть preview как угодно
    preview: str = Field(
        validation_alias=AliasChoices('preview', 'description', 'content_summary', 'text'),
        description="Краткое описание"
    )

class TopicProposal(BaseModel):
    # Позволяем модели называть список тем как угодно
    topics: List[Topic] = Field(
        validation_alias=AliasChoices('topics', 'themes', 'ideas', 'items'),
        description="Список уникальных тем"
    )

class DuplicateCheck(BaseModel):
    is_duplicate: bool = Field(description="Флаг дубликата")
    reason: str = Field(
        validation_alias=AliasChoices('reason', 'explanation', 'verdict', 'analysis'),
        description="Пояснение"
    )

# Состояние графа (State)

class AgentState(TypedDict):
    website_context: str
    channel_archive: str
    objectives: str
    style_guide: str
    suggested_topics: List[Topic]
    selected_topics: List[str]
    final_posts: List[str]
    skip_list: List[str]

# Инициализация LLM
llm = ChatOpenAI(
    base_url=BASE_URL, 
    api_key=API_KEY, 
    model=MODEL_NAME,
    temperature=0.7
)

# %%
# Агенты

def librarian_agent(state: AgentState):
    """Собирает контекст из файлов."""
    def read_file(path, default):
        if os.path.exists(path):
            with open(path, "r", encoding="utf-8") as f:
                return f.read()
        else:
            print('⚠️ Файл не найден:', path)
        return default

    return {
        "website_context": read_file('../DATA/website_content.md', "No website info available."),
        "channel_archive": read_file('../DATA/posts.md', "No archive available."),
        "objectives": read_file('../DATA/objectives.md', "No specific objectives provided.")
    }

def stylist_agent(state: AgentState):
    """Анализирует стиль письма."""
    if "stylist" in state.get("skip_list", []):
        return {"style_guide": "Стандартный информационный стиль."}
    
    prompt = f"Проанализируй стиль этих постов и выдели 5-7 ключевых фишек письма / особенностей написания текстов:\n\n{state['channel_archive']}"
    response = llm.invoke(prompt)
    print(f'Стиль написания: {response.content}')
    return {"style_guide": response.content}

def planner_agent(state: AgentState):
    """Ищет 'пробелы' и предлагает темы."""
    planner_llm = llm.with_structured_output(TopicProposal, method="json_mode")
    
    system_msg = SystemMessage(content=(
        "Ты — контент-стратег. Твоя задача — проанализировать предыдущие посты автора, и на основе этого оопределить следующие темы для написания постов.\n"
        f"ЦЕЛИ: {state['objectives']}\n"
        "Найди темы, которые еще НЕ раскрыты или могут дополнить существующий архив.\n"
        "СТРОГО СОБЛЮДАЙ СТРУКТУРУ JSON: каждое событие в 'topics' "
        "ОБЯЗАТЕЛЬНО должно содержать ключи: 'title', 'tag' и 'preview'." # Явное напоминание
    ))
    
    user_msg = HumanMessage(content=(
        f"Информация о моих предыдущих постах: {state['channel_archive']}\n"
        "Предложи 5-7 уникальных тем."
    ))

    result = planner_llm.invoke([system_msg, user_msg])
    return {"suggested_topics": result.topics}

def gatekeeper_agent(state: AgentState):
    """Проверка на дубликаты."""
    check_llm = llm.with_structured_output(DuplicateCheck, method="json_mode")
    approved = []
    
    for topic in state["suggested_topics"]:
        topic_str = f"{topic.title}: {topic.preview}"
        
        system_msg = SystemMessage(content="Ты шеф-редактор. Сравнивай новую идею с архивом на предмет ИДЕНТИЧНОСТИ советов и выводов.")
        user_msg = HumanMessage(content=(
            f"АРХИВ:\n{state['channel_archive']}\n\n"
            f"НОВАЯ ИДЕЯ:\n{topic_str}\n"
            "Это скучный дубликат? Ответь в JSON."
        ))
        
        res = check_llm.invoke([system_msg, user_msg])
        if not res.is_duplicate:
            approved.append(f"{topic_str} (Контекст: {res.reason})")
            
    return {"selected_topics": approved}

def writer_agent(state: AgentState):
    """Генерация постов (k штук)."""
    if "writer" in state.get("skip_list", []):
        return {"final_posts": ["Writing skipped."]}
    
    generated_posts = []
    # Пишем до 3 постов из одобренных тем
    for topic_context in state["selected_topics"][:3]:
        prompt = f"""
        Напиши пост для Telegram.
        ЦЕЛЬ АВТОРА: {state['objectives']}
        ТЕМА: {topic_context}
        СТИЛЬ: {state['style_guide']}
        КОНТЕКСТ АВТОРА: {state['website_context']}
        ИНФОРМАЦИЯ О ПРЕДЫДУЩИХ ПОСТАХ АВТОРА (ВКЛЮЧАЯ ИХ ТЕКСТ): {state['channel_archive']}

        При написании текста в первую очередь ориентируйся на стиль автора и его предыдущие посты. Твоя задача — создать уникальный и интересный контент, который соответствует видению и стилю автора.
        Пост должен быть информативным, полезным и соответствовать интересам целевой аудитории автора. За счет этого пост будет выглядеть органично в общем контексте канала автора, и будет дополнять предыдущие посты, чтобы читатели узнали что-то новое
        """
        response = llm.invoke(prompt)
        generated_posts.append(response.content)
        
    return {"final_posts": generated_posts}

# Сборка графа

workflow = StateGraph(AgentState)

workflow.add_node("librarian", librarian_agent)
workflow.add_node("stylist", stylist_agent)
workflow.add_node("planner", planner_agent)
workflow.add_node("gatekeeper", gatekeeper_agent)
workflow.add_node("writer", writer_agent)

workflow.set_entry_point("librarian")
workflow.add_edge("librarian", "stylist")
workflow.add_edge("stylist", "planner")
workflow.add_edge("planner", "gatekeeper")
workflow.add_edge("gatekeeper", "writer")
workflow.add_edge("writer", END)

app = workflow.compile()

initial_input = {"skip_list": []} 
try:
    result = app.invoke(initial_input)
    
    print(f"\n✅ Пайплайн завершен. Найдено тем: {len(result['selected_topics'])}")
    print(f"✅ Сгенерировано постов: {len(result['final_posts'])}\n")

    for idx, post in enumerate(result['final_posts'], 1):
        print(f"--- ВАРИАНТ №{idx} ---")
        print(post)
        print("\n" + "="*50 + "\n")
        
except Exception as e:
    print(f"❌ Произошла ошибка: {e}")
# Out:
# Стиль написания: Вот 5-7 ключевых особенностей стиля этих постов:
#
# ### 1. **Разговорный и неформальный тон**
#    - Автор пишет так, будто общается с другом: использует сленг (*"прикольно"*, *"фишки"*, *"загуглите"*), сокращения (*"и так далее"*, *"и так далее"*), и даже эмодзи (в некоторых постах).
#    - Примеры:
#      *"Это не хорошо и не плохо, это просто другое)"*
#      *"Надо сказать чтобы в качестве моральной компенсации пропиарили канал"*
#
# ### 2. **Сравнительный анализ**
#    - Часто проводит параллели между Россией и Китаем, российской и зарубежной системой образования, разными культурами.
#    - Примеры:
#      *"В ВШЭ одно здание находится на Покровке, другое — в двадцати минутах ходьбы..."*
#      *"В России в магистратуру зачастую идут люди с целью сменить специальность..."*
#
# ### 3. **Структурированность и списки**
#    - Многие посты построены по принципу *"тезис → пример → вывод"* или содержат перечисления (топ-3 блюда, различия в учебе и т.д.).
#    - Примеры:
#      *"Топ-три блюда, которые мне понравились больше всего: Малатанг, Курица Кунг Пао, Суань Цай Юй"*
#      *"Ожидания от студентов... Разнообразие специальностей... Прозрачность оценивания"*
#
# ### 4. **Личный опыт и субъективность**
#    - Автор не претендует на объективность, а делится своими наблюдениями и впечатлениями.
#    - Примеры:
#      *"Мне она нравится кисло-острым бульоном"*
#      *"Шанхай на меня произвел большее впечатление, и вот несколько причин"*
#
# ### 5. **Юмор и ирония**
#    - Легкая самоирония и шутки делают тексты живее.
#    - Примеры:
#      *"Загуглите, может когда-нибудь организуем"*
#      *"Недавно были в чайной, и я вспомнил об одном небольшом плюсе жизни в Китае"* (сразу после поста про еду).
#
# ### 6. **Техническая точность (в тематических постах)**
#    - В постах про AI или учебу автор использует термины и конкретные примеры без упрощения.
#    - Примеры:
#      *"LLM рассматриваются как текстовая генерация, где для рекомендательных систем модель генерирует айдишник следующего айтема"*
#      *"В зарубежных магистратурах смотрят на резюме, мотивационное письмо, рекомендательные письма..."*
#
# ### 7. **Визуальные и культурные детали**
#    - Описания часто включают яркие образы (например, *"озеро с черными лебедями"*, *"небоскребы, сочетающиеся с историческими зданиями"*).
#    - Примеры:
#      *"В Чунцине даже есть мороженое, которое заливают маслом чили"*
#      *"Хот спринг — это аналог нашей бани, но с бассейнами и кинотеатром"*
#
# ### **Общий вывод:**
# Стиль сочетает **личностный подход**, **аналитику** и **разговорную манеру**, что делает тексты одновременно информативными и увлекательными. Автор не боится быть субъективным, но при этом подкрепляет мнения фактами и примерами. Такой стиль хорошо работает для блога или канала, где важно удержать внимание читателя.
#
# ✅ Пайплайн завершен. Найдено тем: 6
# ✅ Сгенерировано постов: 3
#
# --- ВАРИАНТ №1 ---
# **Как иностранные студенты адаптируются к китайской культуре: неожиданные трудности и приятные открытия**
#
# Привет! Сегодня хочу поговорить о том, с какими культурными нюансами сталкиваются иностранцы в Китае — и почему это не всегда очевидно. Когда я только приехал, думал, что основная сложность будет в языке. Но на деле оказалось, что есть масса других вещей, которые удивляют, раздражают или, наоборот, приятно поражают.
#
# ### **1. "Лицо" (面子) — невидимый закон общения**
# В Китае очень важно сохранять "лицо" — и своё, и собеседника. Это значит, что публичная критика, отказ или спор могут восприниматься как грубость. Например:
# - Если преподаватель ошибся, студенты вряд ли укажут на это прямо. Скорее, зададут уточняющий вопрос.
# - В переговорах или обсуждениях часто избегают слова "нет". Вместо этого скажут "посмотрим", "возможно" или просто промолчат.
# - Даже в бытовых ситуациях: если официант принес не то блюдо, китайцы вряд ли начнут скандал — просто съедят или вежливо попросят заменить.
#
# Для иностранцев это может быть сложно: мы привыкли к прямому общению, а здесь нужно учиться читать между строк.
#
# ### **2. Коллективизм vs. индивидуализм**
# В России мы часто думаем "я сам", а в Китае — "мы вместе". Это проявляется во всём:
# - **Групповые задания** в универе часто оцениваются как единое целое. Если кто-то не потянул, страдает вся команда.
# - **Общие пространства** (например, в общагах) считаются общими в прямом смысле: можно зайти к соседу без стука, если дверь открыта.
# - **Подарки и внимание** — норма. В России мы можем забыть о дне рождения коллеги, а здесь это может восприняться как неуважение.
#
# С одной стороны, это создаёт ощущение поддержки. С другой — иногда хочется побыть одному, а тебя всё равно тянут в общий чат или на групповое мероприятие.
#
# ### **3. Еда — это ритуал, а не просто питание**
# В Китае еда — это социальный процесс. Несколько неожиданных моментов:
# - **Общий стол**. В России мы заказываем себе блюдо и едим его. Здесь всё делится: большая тарелка в центре, и каждый берёт себе палочками.
# - **Шум — это норма**. В ресторанах часто громко разговаривают, стучат палочками, пьют суп с громким причмокиванием. В России это могло бы считаться дурным тоном, а здесь — признак того, что еда вкусная.
# - **Гостеприимство**. Если китайский друг угощает, отказываться невежливо. Даже если ты уже сытый, нужно хотя бы попробовать.
#
# ### **4. Технологии и цифровая жизнь**
# Китай — это отдельная вселенная в плане технологий:
# - **Безналичная оплата везде**. Даже у уличных торговцев можно расплатиться через WeChat Pay или Alipay. Наличные почти не используют.
# - **QR-коды вместо визиток**. В России мы обмениваемся номерами телефонов, а здесь — сканируют QR-код в WeChat.
# - **Цифровой след**. Многие сервисы требуют привязки к китайскому номеру или ID. Иностранцам иногда приходится просить помощи у местных, чтобы зарегистрироваться.
#
# ### **5. Неожиданные плюсы**
# Не всё сложно — есть и приятные открытия:
# - **Безопасность**. В Пекине или Шанхае можно гулять ночью без опасений.
# - **Удобство**. Доставка еды за 15 минут, метро, которое работает как часы, и везде чистота.
# - **Открытость к иностранцам**. Если ты пытаешься говорить по-китайски (пусть и с ошибками), местные очень радуются и помогают.
#
# ### **Вывод**
# Адаптация — это процесс. Сначала всё кажется странным, потом привыкаешь, а потом начинаешь понимать, что некоторые китайские традиции даже круче наших. Главное — не бояться спрашивать, пробовать и иногда просто принимать, что "здесь так принято".
#
# А у вас были подобные культурные открытия? Делитесь в комментариях! 👇
#
# #жизньвКитае #учебазаграницей #мысли
#
# ==================================================
#
# --- ВАРИАНТ №2 ---
# **Зачем экономистам изучать философию: неочевидные связи между экономикой и мышлением**
#
# Когда я учился на экономиста в ВШЭ, философия казалась чем-то абстрактным и далёким от реальной жизни. Но со временем я понял, что многие философские концепции помогают лучше понимать экономические процессы и принимать решения в условиях неопределенности. Вот несколько примеров:
#
# 1. **Диалектика Гегеля и экономические циклы**
#    Гегель говорил, что развитие происходит через противоречия и их разрешение. Это очень похоже на экономические циклы: кризисы — это не просто падения, а необходимые этапы для перехода к новому уровню. Например, финансовые пузыри лопаются, но после этого рынок адаптируется и появляются новые возможности.
#
# 2. **Утилитаризм Бентама и принятие решений**
#    В экономике часто используют понятие "полезности" — как максимизировать пользу при ограниченных ресурсах. Бентам ввёл идею утилитаризма, где действия оцениваются по их последствиям. Это напрямую связано с тем, как компании и государства выбирают стратегии: что принесёт больше пользы большинству?
#
# 3. **Экзистенциализм и предпринимательство**
#    Сартр говорил, что человек сам создаёт смысл своей жизни. В бизнесе это похоже на стартапы: предприниматель не знает, что получится, но он действует, несмотря на неопределенность. Без риска и веры в собственные силы не было бы инноваций.
#
# 4. **Философия науки Поппера и экономические модели**
#    Поппер утверждал, что научные теории нельзя доказать, но можно опровергнуть. Это очень похоже на экономические модели: они работают, пока не появляются новые данные, которые их опровергают. Например, модели прогнозирования рынка постоянно корректируются.
#
# 5. **Этика Канта и корпоративная ответственность**
#    Кант говорил, что поступки должны быть моральными независимо от последствий. В бизнесе это про этику: компании всё чаще думают не только о прибыли, но и о влиянии на общество и окружающую среду.
#
# **Вывод:** Философия учит думать системно, видеть связи между явлениями и принимать решения в условиях неопределенности. Для экономиста это не просто абстрактные размышления, а инструмент для анализа реальных процессов.
#
# А вы сталкивались с тем, что философские идеи помогали в работе или учёбе? Делитесь в комментариях! 🧠💡
#
# #мысли #экономика #философия #учебазаграницей
#
# ==================================================
#
# --- ВАРИАНТ №3 ---
# **🔥 AI в образовании: как машинное обучение меняет подход к обучению за рубежом**
#
# Привет! Сегодня поговорим о том, как современные университеты используют ИИ для персонализации обучения — тема, которая мне особенно близка, ведь я сам учусь в Цинхуа и работаю с ML.
#
# ### **1. Персонализированные учебные планы**
# В зарубежных вузах (особенно в США и Китае) уже активно применяют адаптивные системы обучения. Например, платформы вроде **Knewton** или **Duolingo** анализируют, как студент усваивает материал, и подстраивают сложность задач под его уровень. В Цинхуа на некоторых курсах используют похожие инструменты — если ты быстро решаешь задачи, система предлагает более сложные, а если застреваешь — дает дополнительные материалы.
#
# *Это как Netflix, но для учебы: вместо рекомендаций фильмов — рекомендации тем для изучения.*
#
# ### **2. Автоматическая проверка работ**
# В России часто приходится ждать недели, пока проверят лабораторную или эссе. В Китае и США многие университеты используют ИИ для оценки письменных работ (например, **Gradescope** или **Turnitin**). Система не только ищет плагиат, но и анализирует структуру, логику и даже стиль написания.
#
# *Плюс: быстрее получаешь фидбек. Минус: иногда ИИ не понимает креативных решений и ставит низкий балл за "нестандартный" ответ.*
#
# ### **3. Виртуальные ассистенты и чат-боты**
# В Цинхуа на некоторых курсах есть боты, которые отвечают на вопросы студентов 24/7. Они не заменяют преподавателей, но помогают разобраться с базовыми вещами (например, объясняют формулы или дают подсказки по коду).
#
# *Прикольно, что иногда бот отвечает лучше, чем некоторые преподаватели на семинарах.*
#
# ### **4. Прогнозирование успеваемости**
# Некоторые университеты используют ML для предсказания, кто может отчислиться или не сдать экзамен. Анализируют активность на платформе, посещаемость и даже время, которое студент тратит на задачи. Если система видит, что ты "проваливаешься", она отправляет уведомление куратору.
#
# *Это как в банке, когда ИИ предсказывает, кто не вернет кредит — только здесь речь о твоей учебе.*
#
# ### **Вывод**
# ИИ в образовании — это не будущее, а уже реальность. В Китае и США это развивается быстрее, чем в России, но тенденция очевидна: обучение становится более гибким, быстрым и адаптивным.
#
# *А что думаете вы? Готовы ли к тому, что ваш следующий преподаватель будет нейросетью? 😉*
#
# #ai #учебазаграницей #мысли
#
# ==================================================
