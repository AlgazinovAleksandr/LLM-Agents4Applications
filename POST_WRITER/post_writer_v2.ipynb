# %%
import os
from typing import TypedDict, List, Optional
from pydantic import BaseModel, Field, AliasChoices
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
from langgraph.graph import StateGraph, END
from constants import BASE_URL, API_KEY, MODEL_NAME

# %%
# Схемы данных (Pydantic)

class Topic(BaseModel):
    title: str = Field(description="Заголовок темы")
    # Делаем тег необязательным. Если его нет, будет пустая строка или default.
    tag: Optional[str] = Field(
        default="#general", 
        description="Тематический тег, например #ai / #жизньвКитае"
    )
    # Позволяем модели называть preview как угодно
    preview: str = Field(
        validation_alias=AliasChoices('preview', 'description', 'content_summary', 'text'),
        description="Краткое описание"
    )

class TopicProposal(BaseModel):
    # Позволяем модели называть список тем как угодно
    topics: List[Topic] = Field(
        validation_alias=AliasChoices('topics', 'themes', 'ideas', 'items'),
        description="Список уникальных тем"
    )

class DuplicateCheck(BaseModel):
    is_duplicate: bool = Field(description="Флаг дубликата")
    reason: str = Field(
        validation_alias=AliasChoices('reason', 'explanation', 'verdict', 'analysis'),
        description="Пояснение"
    )

# Состояние графа (State)

class AgentState(TypedDict):
    website_context: str
    channel_archive: str
    objectives: str
    style_guide: str
    suggested_topics: List[Topic]
    selected_topics: List[str]
    final_posts: List[str]
    skip_list: List[str]

# Инициализация LLM
llm = ChatOpenAI(
    base_url=BASE_URL, 
    api_key=API_KEY, 
    model=MODEL_NAME,
    temperature=0.7
)

# %%
# Агенты

def librarian_agent(state: AgentState):
    """Собирает контекст из файлов."""
    def read_file(path, default):
        if os.path.exists(path):
            with open(path, "r", encoding="utf-8") as f:
                return f.read()
        return default

    return {
        "website_context": read_file('website_content.md', "No website info available."),
        "channel_archive": read_file('posts.md', "No archive available."),
        "objectives": read_file('objectives.md', "No specific objectives provided.")
    }

def stylist_agent(state: AgentState):
    """Анализирует стиль письма."""
    if "stylist" in state.get("skip_list", []):
        return {"style_guide": "Стандартный информационный стиль."}
    
    prompt = f"Проанализируй стиль этих постов и выдели 5-7 ключевых фишек письма / особенностей написания текстов:\n\n{state['channel_archive']}"
    response = llm.invoke(prompt)
    print(f'Стиль написания: {response.content}')
    return {"style_guide": response.content}

def planner_agent(state: AgentState):
    """Ищет 'пробелы' и предлагает темы."""
    planner_llm = llm.with_structured_output(TopicProposal, method="json_mode")
    
    system_msg = SystemMessage(content=(
        "Ты — контент-стратег. Твоя задача — проанализировать предыдущие посты автора, и на основе этого оопределить следующие темы для написания постов.\n"
        f"ЦЕЛИ: {state['objectives']}\n"
        "Найди темы, которые еще НЕ раскрыты или могут дополнить существующий архив.\n"
        "СТРОГО СОБЛЮДАЙ СТРУКТУРУ JSON: каждое событие в 'topics' "
        "ОБЯЗАТЕЛЬНО должно содержать ключи: 'title', 'tag' и 'preview'." # Явное напоминание
    ))
    
    user_msg = HumanMessage(content=(
        f"Информация о моих предыдущих постах: {state['channel_archive']}\n"
        "Предложи 5-7 уникальных тем."
    ))

    result = planner_llm.invoke([system_msg, user_msg])
    return {"suggested_topics": result.topics}

def gatekeeper_agent(state: AgentState):
    """Проверка на дубликаты."""
    check_llm = llm.with_structured_output(DuplicateCheck, method="json_mode")
    approved = []
    
    for topic in state["suggested_topics"]:
        topic_str = f"{topic.title}: {topic.preview}"
        
        system_msg = SystemMessage(content="Ты шеф-редактор. Сравнивай новую идею с архивом на предмет ИДЕНТИЧНОСТИ советов и выводов.")
        user_msg = HumanMessage(content=(
            f"АРХИВ:\n{state['channel_archive']}\n\n"
            f"НОВАЯ ИДЕЯ:\n{topic_str}\n"
            "Это скучный дубликат? Ответь в JSON."
        ))
        
        res = check_llm.invoke([system_msg, user_msg])
        if not res.is_duplicate:
            approved.append(f"{topic_str} (Контекст: {res.reason})")
            
    return {"selected_topics": approved}

def writer_agent(state: AgentState):
    """Генерация постов (k штук)."""
    if "writer" in state.get("skip_list", []):
        return {"final_posts": ["Writing skipped."]}
    
    generated_posts = []
    # Пишем до 3 постов из одобренных тем
    for topic_context in state["selected_topics"][:3]:
        prompt = f"""
        Напиши пост для Telegram.
        ЦЕЛЬ АВТОРА: {state['objectives']}
        ТЕМА: {topic_context}
        СТИЛЬ: {state['style_guide']}
        КОНТЕКСТ АВТОРА: {state['website_context']}
        ИНФОРМАЦИЯ О ПРЕДЫДУЩИХ ПОСТАХ АВТОРА (ВКЛЮЧАЯ ИХ ТЕКСТ): {state['channel_archive']}

        При написании текста в первую очередь ориентируйся на стиль автора и его предыдущие посты. Твоя задача — создать уникальный и интересный контент, который соответствует видению и стилю автора.
        Пост должен быть информативным, полезным и соответствовать интересам целевой аудитории автора. За счет этого пост будет выглядеть органично в общем контексте канала автора, и будет дополнять предыдущие посты, чтобы читатели узнали что-то новое
        """
        response = llm.invoke(prompt)
        generated_posts.append(response.content)
        
    return {"final_posts": generated_posts}

# Сборка графа

workflow = StateGraph(AgentState)

workflow.add_node("librarian", librarian_agent)
workflow.add_node("stylist", stylist_agent)
workflow.add_node("planner", planner_agent)
workflow.add_node("gatekeeper", gatekeeper_agent)
workflow.add_node("writer", writer_agent)

workflow.set_entry_point("librarian")
workflow.add_edge("librarian", "stylist")
workflow.add_edge("stylist", "planner")
workflow.add_edge("planner", "gatekeeper")
workflow.add_edge("gatekeeper", "writer")
workflow.add_edge("writer", END)

app = workflow.compile()

initial_input = {"skip_list": []} 
try:
    result = app.invoke(initial_input)
    
    print(f"\n✅ Пайплайн завершен. Найдено тем: {len(result['selected_topics'])}")
    print(f"✅ Сгенерировано постов: {len(result['final_posts'])}\n")

    for idx, post in enumerate(result['final_posts'], 1):
        print(f"--- ВАРИАНТ №{idx} ---")
        print(post)
        print("\n" + "="*50 + "\n")
        
except Exception as e:
    print(f"❌ Произошла ошибка: {e}")
# Out:
# Стиль написания: Вот **5-7 ключевых фишек стиля** этих постов, которые делают их узнаваемыми и эффективными:
#
# ### 1. **Разговорный, но структурированный стиль**
#    - Тексты написаны **легко и естественно**, как будто автор общается с другом (например, *"При этом что самое интересное..."*, *"Это не хорошо и не плохо, это просто другое)"*).
#    - При этом **логика изложения четкая**: часто есть вводная часть, основной блок с примерами и вывод/рефлексия.
#    - Используются **разговорные обороты** (*"прикольно", "курс закончился в начале ноября, а финальные результаты стали доступны к просмотру в середине января"*).
#
# ### 2. **Сравнения и контрасты**
#    - Автор активно **сопоставляет опыт** (Россия vs Китай, ВШЭ vs Цинхуа, классический ML vs LLM).
#    - Это создает **контекст для читателя** и делает текст более убедительным.
#    - Примеры:
#      *"В России в магистратуру зачастую идут люди с целью сменить специальность. В хороших зарубежных магистратурах сильно реже встречаются студенты, которые на бакалавриате изучали что-то совсем другое"*.
#      *"Пекин больше ощущается как объединение нескольких городов, и иногда поездка в другой район воспринимается как мини-командировка"*.
#
# ### 3. **Конкретика и детали**
#    - Много **конкретных примеров, цифр, названий** (блюда, чаи, университетские особенности).
#    - Это усиливает **достоверность** и погружает читателя в контекст.
#    - Примеры:
#      *"В Чунцине даже есть мороженое, которое заливают маслом чили"*.
#      *"Пекин - это огромный город площадью 16 400 км (для сравнения, Москва - 2560 км, Шанхай - 6340)"*.
#
# ### 4. **Юмор и ирония**
#    - Легкая **самоирония** и шутки делают тексты более живыми.
#    - Примеры:
#      *"Почему в тренажерке 2/3 девушек и каждый третий парень снимают на видео как они качаются? 非常不好, не дают спокойно потренироваться. Надо сказать чтобы в качестве моральной компенсации пропиарили канал"*.
#      *"Про ту самую, которую так боится и старается избегать русский турист)"*.
#
# ### 5. **Лаконичность и отсутствие "воды"**
#    - Посты **короткие, но емкие** – нет лишних вступлений или отступлений.
#    - Каждая фраза несет смысловую нагрузку.
#    - Пример: пост про LLM – всего 4 абзаца, но в них **четко объяснена суть проблемы, примеры и вывод**.
#
# ### 6. **Использование списков и перечислений**
#    - Часто встречаются **маркированные списки** (топ-3 блюда, виды чая, отличия в учебе).
#    - Это улучшает **читаемость** и помогает структурировать информацию.
#    - Пример:
#      *"Топ-три блюда, которые мне понравились больше всего:
#      - Малатанг (麻辣烫)...
#      - Курица Кунг Пао (宫保鸡丁)...
#      - Суань Цай Юй (酸菜鱼)..."*
#
# ### 7. **Личный опыт + универсальные истины**
#    - Автор **делится своим опытом**, но при этом **обобщает** его до полезных инсайтов.
#    - Это делает тексты **полезными не только для узкой аудитории**, но и для широкого круга читателей.
#    - Примеры:
#      *"В таком контексте перфекционизм зачастую является злом"* (из поста про закон Парето).
#      *"Это не значит, что задачи нужно делать некачественно. Это значит, что нужно уметь грамотно понимать критерии качества..."*.
#
# ---
# ### **Бонус: Особенности оформления**
# - **Заголовки** часто содержат **уточнения** (*"часть 1"*, *"про разное"*), что помогает ориентироваться в серии постов.
# - **Теги** (#жизньвКитае, #учебазаграницей) используются для **категоризации контента**.
# - **Эмодзи и смайлы** отсутствуют, но тон остается **дружелюбным и неформальным**.
#
# Этот стиль **сочетает экспертность, личный опыт и легкость изложения**, что делает посты интересными как для узкой аудитории (студенты, IT-специалисты), так и для широкого круга читателей.
#
# ✅ Пайплайн завершен. Найдено тем: 6
# ✅ Сгенерировано постов: 3
#
# --- ВАРИАНТ №1 ---
# **Скрытые культурные различия: что удивило в Китае**
#
# Когда живешь в другой стране, начинаешь замечать мелочи, которые не бросаются в глаза туристу. В Китае таких нюансов особенно много — они не очевидны, но сильно влияют на повседневную жизнь. Вот несколько наблюдений, которые меня удивили:
#
# 1. **Отсутствие "личного пространства" в общественных местах**
#    В России мы привыкли к тому, что в метро или очереди люди стараются держать дистанцию. В Китае это не так: в метро можно оказаться буквально прижатым к незнакомцу, а в очереди люди часто стоят вплотную. Это не грубость — просто другая норма. При этом китайцы очень вежливы в общении, просто физические границы воспринимаются иначе.
#
# 2. **Культ "сохранения лица" (面子, miànzi)**
#    В России мы можем открыто критиковать или спорить, не задумываясь о последствиях. В Китае это почти табу. "Сохранение лица" — это не только о репутации, но и о том, чтобы не ставить человека в неловкое положение. Например, если кто-то ошибся, его не будут публично стыдить, а постараются решить вопрос деликатно.
#
# 3. **Отсутствие "прямого отказа"**
#    В России "нет" — это "нет". В Китае часто отвечают уклончиво: "посмотрим", "возможно", "давайте обсудим позже". Это не значит, что человек согласен — просто он избегает прямого отказа, чтобы не обидеть. Приходится учиться читать между строк.
#
# 4. **Другое отношение к времени**
#    В России опоздание на 10 минут — это почти норма. В Китае пунктуальность ценится гораздо выше, особенно в деловой среде. Но при этом есть и обратная сторона: иногда процессы могут растягиваться из-за бюрократии или неявных правил.
#
# 5. **Уважение к старшим — не просто слова**
#    В России мы можем обращаться к преподавателю или начальнику на "ты", если отношения неформальные. В Китае это почти невозможно — иерархия очень важна. Даже в разговоре с одногруппником старше на год можно услышать уважительное "学长" (сюэчжан — "старший студент").
#
# Это не хорошо и не плохо — просто другое. Именно такие мелочи делают жизнь в Китае интересной и иногда неожиданной.
#
# #жизньвКитае #культурныеразличия
#
# ==================================================
#
# --- ВАРИАНТ №2 ---
# **Как иностранцу выжить в китайском университете: лайфхаки**
#
# Учеба в Китае — это не только про академические вызовы, но и про адаптацию к другой культуре, системе образования и даже способу общения с преподавателями. Вот несколько практических советов, которые помогут не потеряться в китайском университете.
#
# ### 1. **Общение с преподавателями: иерархия и уважение**
# В Китае отношение к преподавателям более формальное, чем в России или на Западе. Не стоит обращаться к ним по имени (даже если они молодые) — лучше использовать "Professor + фамилия". Если нужно задать вопрос, лучше сделать это после лекции или по почте, а не перебивать во время занятия.
#
# *Лайфхак:* Если преподаватель говорит по-китайски, а вы не понимаете, не стесняйтесь попросить повторить на английском. Многие профессора в топовых вузах (например, в Цинхуа) хорошо владеют им, но могут забывать переключаться.
#
# ### 2. **Учебный процесс: проекты вместо семинаров**
# В отличие от российских университетов, где много семинаров и домашних заданий, в Китае акцент делается на самостоятельную работу и проекты. Лекции часто проходят в формате "слушай и конспектируй", а основная нагрузка — на финальный проект или исследовательскую работу.
#
# *Лайфхак:* Не откладывайте проекты на последний момент. В Китае дедлайны жесткие, и переносов почти не бывает. Если нужно согласовать тему с преподавателем, делайте это заранее — китайские профессора могут долго отвечать на письма.
#
# ### 3. **Оценки: анонимность и неожиданности**
# В китайских университетах оценки часто анонимны — вы не увидите баллы других студентов, а иногда даже свои результаты становятся известны только через месяц после экзамена. Это может быть стрессово, но так устроена система.
#
# *Лайфхак:* Если хотите понять, как у вас дела, спрашивайте у преподавателя обратную связь во время курса. Многие идут навстречу, если видят, что студент действительно заинтересован.
#
# ### 4. **Культурные нюансы: групповая работа и "лицо"**
# В Китае очень важно понятие "лицо" (面子) — репутация и уважение. Если вы критикуете чью-то работу в группе, делайте это деликатно, чтобы не поставить человека в неловкое положение.
#
# *Лайфхак:* Если вам нужно отказаться от чего-то (например, от участия в мероприятии), сделайте это вежливо и с объяснением. В Китае прямой отказ без причины может восприниматься как неуважение.
#
# ### 5. **Бюрократия: документы и визы**
# В китайских университетах много бумажной работы — от регистрации в кампусе до продления визы. Не откладывайте эти вопросы на последний момент, иначе рискуете столкнуться с очередями и задержками.
#
# *Лайфхак:* Если вам нужно что-то оформить, идите в административный офис утром — так меньше народу. И всегда берите с собой паспорт и студенческий билет.
#
# ### Вывод
# Учеба в Китае — это не только про академические знания, но и про адаптацию к другой системе ценностей. Если научиться работать с этими особенностями, процесс станет намного проще и даже интереснее.
#
# #учебазаграницей #жизньвКитае #лайфхаки
#
# ==================================================
#
# --- ВАРИАНТ №3 ---
# **Экономика через призму философии: почему цифры не всегда правда**
#
# В экономике мы привыкли опираться на данные. ВВП, инфляция, безработица — все это цифры, которые кажутся объективными. Но что, если я скажу, что эти цифры не всегда отражают реальность? И здесь на помощь приходит философия.
#
# ### **1. Проблема измерения**
# Философия науки учит нас, что любое измерение — это упрощение. Например, ВВП не учитывает неформальную экономику, домашний труд или экологические издержки. Как сказал экономист Саймон Кузнец (создатель концепции ВВП): *"Национальный доход должен быть использован для измерения экономического благополучия, но не для измерения счастья."*
#
# ### **2. Контекст важнее цифр**
# В Китае я столкнулся с тем, что экономические показатели могут интерпретироваться по-разному. Например, высокий рост ВВП может быть связан с государственными инвестициями, а не с реальным улучшением жизни людей. Философы-прагматики (вроде Джона Дьюи) говорили, что истина зависит от контекста — и в экономике это особенно актуально.
#
# ### **3. Иллюзия объективности**
# Данные всегда собираются кем-то и для кого-то. Как сказал Мишель Фуко, *"знание — это власть"*. Экономические показатели могут быть инструментом манипуляции. Например, инфляция может быть рассчитана по-разному в зависимости от того, что выгодно правительству или бизнесу.
#
# ### **Вывод**
# Цифры — это не абсолютная истина, а инструмент. Они полезны, но их нужно интерпретировать критически. Как экономист и айтишник, я вижу, что данные — это всего лишь модель реальности, а не сама реальность.
#
# #мысли #экономика #философия
#
# ---
# *P.S. Если вам интересно, как это работает на практике — в следующих постах могу рассказать про конкретные кейсы из Китая и России.*
#
# ==================================================
